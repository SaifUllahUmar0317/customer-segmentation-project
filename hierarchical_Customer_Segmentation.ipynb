# %%
import pandas as pd
import numpy as np
import sklearn.cluster._agglomerative
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
dataset = pd.read_csv("C:\\Users\\student\\Desktop\\Machine learning\\week6\\Mall_Customers.csv")

# %%
dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
X = dataset.iloc[:,[3,4]].values

# %%
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
linkage_data = linkage(scaled_X, method="ward")
plt.figure(figsize=(6,4))
dendrogram(linkage_data)
plt.title("Dendrogram")
plt.xlabel("Data points")
plt.ylabel("Distances")
plt.show()

# %%
clusters = 5 # this is from the dendrogram

# %%
model = AgglomerativeClustering(n_clusters = clusters, linkage = "ward", metric= "euclidean")

# %%
labels = model.fit_predict(scaled_X)

# %%
for i in range(5):
    plt.scatter(scaled_X[labels == i,0], scaled_X[labels == i,1], label = f"{i}")
plt.title("Clusters")
plt.xlabel("income")
plt.ylabel("Spending")
plt.legend()
plt.show()

# %%
# VIP customer = 1
# Inactive customer = 4
# Balanced customer = 2
# saver customer = 0
# Spender customer = 3
